# %%
import tkinter

root = tkinter.Tk()
root.title("QUIZ")
root.geometry('700x900')

c = 0

label_t = tkinter.Label(root, text="QUIZ", font=("arial", 50))
label_t.place(x=250, y=50)

label_u = tkinter.Label(root, text="Username", font=("arial", 30))
label_u.place(x=150, y=150)

entry = tkinter.Entry(root, font=("arial", 30))
entry.place(x=400, y=150)

def increase():
    global c
    c += 1

def info1():
    global c, name, label_t, label_u, entry, button
    name = entry.get()
    label_q1 = tkinter.Label(root, text="Question 1", font=("Arial", 35))
    label_q1.place(x=550, y=50)
    label1 = tkinter.Label(root, text="Which of them is a Keyword in Python?", font=("Arial", 30))
    label1.place(x=300, y=100)

    op1 = tkinter.Button(root, text="range", font=("Arial", 20), command=info2)
    op1.place(x=400, y=200)
    op2 = tkinter.Button(root, text="def", font=("Arial", 20), command=lambda: [info2(), increase()])
    op2.place(x=800, y=200)
    op3 = tkinter.Button(root, text="Val", font=("Arial", 20), command=info2)
    op3.place(x=400, y=300)
    op4 = tkinter.Button(root, text="to", font=("Arial", 20), command=info2)
    op4.place(x=800, y=300)

    label_t.destroy()
    label_u.destroy()
    entry.destroy()
    button.destroy()

def info2():
    global c, label_q1, label1, op1, op2, op3, op4
    label_q2 = tkinter.Label(root, text="Question 2", font=("Arial", 35))
    label_q2.place(x=550, y=50)
    label2 = tkinter.Label(root, text="Which of the following is a built-in function in Python?", font=("Arial", 30))
    label2.place(x=300, y=100)

    opp1 = tkinter.Button(root, text="factorial()", font=("Arial", 20), command=info3)
    opp1.place(x=400, y=200)
    opp2 = tkinter.Button(root, text="print()", font=("Arial", 20), command=lambda: [info3(), increase()])
    opp2.place(x=800, y=200)
    opp3 = tkinter.Button(root, text="seed()", font=("Arial", 20), command=info3)
    opp3.place(x=400, y=300)
    opp4 = tkinter.Button(root, text="sqrt()", font=("Arial", 20), command=info3)
    opp4.place(x=800, y=300)

    label_q1.destroy()
    label1.destroy()
    op1.destroy()
    op2.destroy()
    op3.destroy()
    op4.destroy()

def info3():
    global c, opp1, opp2, opp3, opp4, label_q2, label2
    label_q3 = tkinter.Label(root, text="Question 3", font=("Arial", 35))
    label_q3.place(x=550, y=50)
    label3 = tkinter.Label(root, text="Which of the following is not a core datatype in Python?", font=("Arial", 30))
    label3.place(x=200, y=100)

    oppp1 = tkinter.Button(root, text="Tuple", font=("Arial", 20), width=8, command=info4)
    oppp1.place(x=400, y=200)
    oppp2 = tkinter.Button(root, text="Dictionary", font=("Arial", 20), width=7, command=info4)
    oppp2.place(x=800, y=200)
    oppp3 = tkinter.Button(root, text="Lists", font=("Arial", 20), width=7, command=info4)
    oppp3.place(x=400, y=300)
    oppp4 = tkinter.Button(root, text="Class", font=("Arial", 20), command=lambda: [info4(), increase()])
    oppp4.place(x=800, y=300)

    opp1.destroy()
    opp2.destroy()
    opp3.destroy()
    opp4.destroy()
    label_q2.destroy()
    label2.destroy()

def info4():
    global c, oppp1, oppp2, oppp3, oppp4, label_q3, label3
    label_q4 = tkinter.Label(root, text="Question 4", font=("Arial", 38))
    label_q4.place(x=550, y=50)
    label4 = tkinter.Label(root, text="Who developed the Python programming language?", font=("Arial", 35))
    label4.place(x=200, y=100)

    opppp1 = tkinter.Button(root, text="Wick Van Rossum", font=("Arial", 20), command=info5)
    opppp1.place(x=400, y=200)
    opppp2 = tkinter.Button(root, text="Rasmus Lerdorf", font=("Arial", 20), command=info5)
    opppp2.place(x=800, y=200)
    opppp3 = tkinter.Button(root, text="Guido Van Rossum", font=("Arial", 20), command=lambda: [info5(), increase()])
    opppp3.place(x=400, y=300)
    opppp4 = tkinter.Button(root, text="Niene Stom", font=("Arial", 20), command=info5)
    opppp4.place(x=800, y=300)

    label_q3.destroy()
    label3.destroy()
    oppp1.destroy()
    oppp2.destroy()
    oppp3.destroy()
    oppp4.destroy()

def info5():
    global c, opppp1, opppp2, opppp3, opppp4, label_q4, label4
    label_q5 = tkinter.Label(root, text="Question 5", font=("Arial", 38))
    label_q5.place(x=550, y=50)
    label5 = tkinter.Label(root, text="Which of the following is the extension for Python file?", font=("Arial", 35))
    label5.place(x=150, y=100)

    oppppp1 = tkinter.Button(root, text=".python", font=("Arial", 20), width=15, command=info6)
    oppppp1.place(x=400, y=200)
    oppppp2 = tkinter.Button(root, text=".p", font=("Arial", 20), width=13, command=info6)
    oppppp2.place(x=800, y=200)
    oppppp3 = tkinter.Button(root, text=".pl", font=("Arial", 20), width=16, command=info6)
    oppppp3.place(x=400, y=300)
    oppppp4 = tkinter.Button(root, text=".py", font=("Arial", 20), width=10, command=lambda: [info6(), increase()])
    oppppp4.place(x=800, y=300)

    label_q4.destroy()
    label4.destroy()
    opppp1.destroy()
    opppp2.destroy()
    opppp3.destroy()
    opppp4.destroy()

def info6():
    global c, name, oppppp1, oppppp2, oppppp3, oppppp4, label_q5, label5
    label_q6 = tkinter.Label(root, text="Question 6", font=("Arial", 38))
    label_q6.place(x=550, y=50)
    label6 = tkinter.Label(root, text="What is the correct file extension for Python files?", font=("Arial", 35))
    label6.place(x=150, y=100)

    opppppp1 = tkinter.Button(root, text=".pyth", font=("Arial", 20), width=15, command=info7)
    opppppp1.place(x=400, y=200)
    opppppp2 = tkinter.Button(root, text=".pt", font=("Arial", 20), width=13, command=info7)
    opppppp2.place(x=800, y=200)
    opppppp3 = tkinter.Button(root, text=".py", font=("Arial", 20), width=16, command=lambda: [info7(), increase()])
    opppppp3.place(x=400, y=300)
    opppppp4 = tkinter.Button(root, text=".pyt", font=("Arial", 20), width=10, command=info7)
    opppppp4.place(x=800, y=300)

    label_q5.destroy()
    label5.destroy()
    oppppp1.destroy()
    oppppp2.destroy()
    oppppp3.destroy()
    oppppp4.destroy()

def info7():
    global c, opppppp1, opppppp2, opppppp3, opppppp4, label_q6, label6
    label_q7 = tkinter.Label(root, text="Question 7", font=("Arial", 38))
    label_q7.place(x=550, y=50)
    label7 = tkinter.Label(root, text="Which one is not a reserved keyword in Python?", font=("Arial", 35))
    label7.place(x=200, y=100)

    oppppppp1 = tkinter.Button(root, text="False", font=("Arial", 20), width=10, command=info8)
    oppppppp1.place(x=400, y=200)
    oppppppp2 = tkinter.Button(root, text="none", font=("Arial", 20), width=10, command=lambda: [info8(), increase()])
    oppppppp2.place(x=800, y=200)
    oppppppp3 = tkinter.Button(root, text="return", font=("Arial", 20), width=10, command=info8)
    oppppppp3.place(x=400, y=300)
    oppppppp4 = tkinter.Button(root, text="yield", font=("Arial", 20), width=10, command=info8)
    oppppppp4.place(x=800, y=300)

    label_q6.destroy()
    label6.destroy()
    opppppp1.destroy()
    opppppp2.destroy()
    opppppp3.destroy()
    opppppp4.destroy()

def info8():
    global c, oppppppp1, oppppppp2, oppppppp3, oppppppp4, label_q7, label7
    label_q8 = tkinter.Label(root, text="Question 8", font=("Arial", 38))
    label_q8.place(x=550, y=50)
    label8 = tkinter.Label(root, text="Which one is immutable in Python?", font=("Arial", 35))
    label8.place(x=200, y=100)

    opppppppp1 = tkinter.Button(root, text="List", font=("Arial", 20), width=10, command=info9)
    opppppppp1.place(x=400, y=200)
    opppppppp2 = tkinter.Button(root, text="Dictionary", font=("Arial", 20), width=10, command=info9)
    opppppppp2.place(x=800, y=200)
    opppppppp3 = tkinter.Button(root, text="Tuple", font=("Arial", 20), width=10, command=lambda: [info9(), increase()])
    opppppppp3.place(x=400, y=300)
    opppppppp4 = tkinter.Button(root, text="Set", font=("Arial", 20), width=10, command=info9)
    opppppppp4.place(x=800, y=300)

    label_q7.destroy()
    label7.destroy()
    oppppppp1.destroy()
    oppppppp2.destroy()
    oppppppp3.destroy()
    oppppppp4.destroy()

def info9():
    global c, opppppppp1, opppppppp2, opppppppp3, opppppppp4, label_q8, label8
    label_q9 = tkinter.Label(root, text="Question 9", font=("Arial", 38))
    label_q9.place(x=550, y=50)
    label9 = tkinter.Label(root, text="Which is the correct way to create a function in Python?", font=("Arial", 35))
    label9.place(x=200, y=100)

    oppppppppp1 = tkinter.Button(root, text="create myFunction():", font=("Arial", 20), width=20, command=info10)
    oppppppppp1.place(x=400, y=200)
    oppppppppp2 = tkinter.Button(root, text="def myFunction():", font=("Arial", 20), width=20, command=lambda: [info10(), increase()])
    oppppppppp2.place(x=800, y=200)
    oppppppppp3 = tkinter.Button(root, text="function myFunction():", font=("Arial", 20), width=20, command=info10)
    oppppppppp3.place(x=400, y=300)
    oppppppppp4 = tkinter.Button(root, text="None of the above", font=("Arial", 20), width=20, command=info10)
    oppppppppp4.place(x=800, y=300)

    label_q8.destroy()
    label8.destroy()
    opppppppp1.destroy()
    opppppppp2.destroy()
    opppppppp3.destroy()
    opppppppp4.destroy()

def info10():
    global c, oppppppppp1, oppppppppp2, oppppppppp3, oppppppppp4, label_q9, label9
    label_q10 = tkinter.Label(root, text="Question 10", font=("Arial", 38))
    label_q10.place(x=550, y=50)
    label10 = tkinter.Label(root, text="What is the output of print(2**3)?", font=("Arial", 35))
    label10.place(x=200, y=100)

    opppppppppp1 = tkinter.Button(root, text="6", font=("Arial", 20), width=10, command=show_score)
    opppppppppp1.place(x=400, y=200)
    opppppppppp2 = tkinter.Button(root, text="8", font=("Arial", 20), width=10, command=lambda: [show_score(), increase()])
    opppppppppp2.place(x=800, y=200)
    opppppppppp3 = tkinter.Button(root, text="9", font=("Arial", 20), width=10, command=show_score)
    opppppppppp3.place(x=400, y=300)
    opppppppppp4 = tkinter.Button(root, text="12", font=("Arial", 20), width=10, command=show_score)
    opppppppppp4.place(x=800, y=300)

    label_q9.destroy()
    label9.destroy()
    oppppppppp1.destroy()
    oppppppppp2.destroy()
    oppppppppp3.destroy()
    oppppppppp4.destroy()

def show_score():
    global c, name, opppppppppp1, opppppppppp2, opppppppppp3, opppppppppp4, label_q10, label10
    label_score = tkinter.Label(root, text="SCORE", font=("Arial", 38))
    label_score.place(x=550, y=50)
    label_name = tkinter.Label(root, text=name, font=("Arial", 35))
    label_name.place(x=150, y=200)
    label_count = tkinter.Label(root, text=c, font=("Arial", 30))
    label_count.place(x=400, y=200)

    label_q10.destroy()
    label10.destroy()
    opppppppppp1.destroy()
    opppppppppp2.destroy()
    opppppppppp3.destroy()
    opppppppppp4.destroy()
button = tkinter.Button(root, text="ENTER", font=("arial", 30), command=info1) 
button.place(x=600, y=350) 
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\ABHINAV\anaconda3\Lib\tkinter\__init__.py", line 1968, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\ABHINAV\AppData\Local\Temp\ipykernel_8496\1820493152.py", line 32, in <lambda>
#     op2 = tkinter.Button(root, text="def", font=("Arial", 20), command=lambda: [info2(), increase()])
#                                                                                 ^^^^^^^
#   File "C:\Users\ABHINAV\AppData\Local\Temp\ipykernel_8496\1820493152.py", line 60, in info2
#     label_q1.destroy()
#   File "C:\Users\ABHINAV\anaconda3\Lib\tkinter\__init__.py", line 2667, in destroy
#     self.tk.call('destroy', self._w)
# _tkinter.TclError: can't invoke "destroy" command: application has been destroyed
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\ABHINAV\anaconda3\Lib\tkinter\__init__.py", line 1968, in __call__
# ...
